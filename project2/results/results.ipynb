# %% [markdown]
# ### Simple Toeplitz for Methods

# %%
df = pd.read_csv("toeplitz_methods.csv")

# %%
pd.options.display.float_format = '{:.10e}'.format
print(df.to_latex())
# Out:
# \begin{tabular}{lrr}
# \toprule
# {} &            exact &          numeric \\
# \midrule
# 0 & 8.1014052771e+00 & 8.1014062027e+00 \\
# 1 & 3.1749293434e+01 & 3.1749318745e+01 \\
# 2 & 6.9027853211e+01 & 6.9027858255e+01 \\
# 3 & 1.1691699740e+02 & 1.1691701506e+02 \\
# 4 & 1.7153703235e+02 & 1.7153703274e+02 \\
# 5 & 2.2846296765e+02 & 2.2846301971e+02 \\
# 6 & 2.8308300260e+02 & 2.8308304077e+02 \\
# 7 & 3.3097214679e+02 & 3.3097216033e+02 \\
# 8 & 3.6825070657e+02 & 3.6825073262e+02 \\
# 9 & 3.9189859472e+02 & 3.9189859742e+02 \\
# \bottomrule
# \end{tabular}

# %%
pd.options.display.float_format = '{:.7e}'.format
df = pd.read_csv("poly_toeplitz_methods_10n.csv")
print(df.to_latex())
# Out:
# \begin{tabular}{lrr}
# \toprule
# {} &         exact &       numeric \\
# \midrule
# 0 & 8.1014053e+00 & 8.1014062e+00 \\
# 1 & 3.1749293e+01 & 3.1749319e+01 \\
# 2 & 6.9027853e+01 & 6.9027858e+01 \\
# 3 & 1.1691700e+02 & 1.1691702e+02 \\
# 4 & 1.7153703e+02 & 1.7153703e+02 \\
# 5 & 2.2846297e+02 & 2.2846302e+02 \\
# 6 & 2.8308300e+02 & 2.8308304e+02 \\
# 7 & 3.3097215e+02 & 3.3097216e+02 \\
# 8 & 3.6825071e+02 & 3.6825073e+02 \\
# 9 & 3.9189859e+02 & 3.9189860e+02 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ### Eigenvecs

# %%
df = pd.read_csv("eigenvecs.csv")
#df = np.abs(df)

# %%
df.plot.bar(y=df.columns.difference(["exact","rotated"]), legend=False)
# Out:
# <AxesSubplot:>

# %%
df.plot.bar(y=["s1"], legend=False)
# Out:
# <AxesSubplot:>

# %%
df.plot.bar(y=["exact","rotated"])
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv("rotations_for_varying_n.csv")

# %%
df.plot(x="n")
# Out:
# <AxesSubplot:xlabel='n'>

# %%
pd.options.display.float_format = '{:.3e}'.format
df = pd.read_csv("jacobi_general_compare.csv")
df["rho=10"] = pd.read_csv("jacobi_general_compare_10.csv")["numeric"]
df["rho=20"] = pd.read_csv("jacobi_general_compare_20.csv")["numeric"]
#print(df.to_latex())

# %%
pd.options.display.float_format = '{:.6e}'.format
df = pd.read_csv("poly_general_compare.csv")
df["rho=10"] = pd.read_csv("poly_general_compare_10.csv")["numeric"]
df["rho=20"] = pd.read_csv("poly_general_compare_20.csv")["numeric"]
df["rho=100"] = pd.read_csv("poly_general_compare_100.csv")["numeric"]
print(df.to_latex())
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
# {} &        exact &      numeric &       rho=10 &       rho=20 &      rho=100 \\
# \midrule
# 0   & 3.000000e+00 & 2.999877e+00 & 2.999877e+00 & 2.999503e+00 & 2.987443e+00 \\
# 1   & 7.000000e+00 & 6.999376e+00 & 6.999376e+00 & 6.997501e+00 & 6.936919e+00 \\
# 2   & 1.100000e+01 & 1.099848e+01 & 1.099848e+01 & 1.099390e+01 & 1.084529e+01 \\
# 3   & 1.500000e+01 & 1.499717e+01 & 1.499717e+01 & 1.498869e+01 & 1.471188e+01 \\
# 4   & 1.900000e+01 & 1.899548e+01 & 1.899548e+01 & 1.898188e+01 & 1.853599e+01 \\
# 5   & 2.300000e+01 & 2.299338e+01 & 2.299338e+01 & 2.297347e+01 & 2.231685e+01 \\
# 6   & 2.700000e+01 & 2.699087e+01 & 2.699087e+01 & 2.696345e+01 & 2.605366e+01 \\
# 7   & 3.100000e+01 & 3.098797e+01 & 3.098797e+01 & 3.095183e+01 & 2.974558e+01 \\
# 8   & 3.500000e+01 & 3.498467e+01 & 3.498467e+01 & 3.493859e+01 & 3.339169e+01 \\
# 9   & 3.900000e+01 & 3.898097e+01 & 3.898097e+01 & 3.892375e+01 & 3.699102e+01 \\
# ...

# %%
pd.options.display.float_format = '{:.6e}'.format
df = pd.read_csv("poly_general_compare.csv")
#print(df.to_latex())
