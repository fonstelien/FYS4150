# %%
def plot_trajectories(fname):
    df = pd.read_csv(fname)
    fix, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,6))
    axes[0].scatter(df['euler_pos0'], df['euler_pos1'], s=.1)
    axes[0].scatter(df['euler_pos0'].iloc[0], df['euler_pos1'].iloc[0], s=50)
    axes[0].scatter(df['euler_pos0'].iloc[-1], df['euler_pos1'].iloc[-1], s=50)
    axes[1].scatter(df['verlet_pos0'], df['verlet_pos1'], s=.1)
    axes[1].scatter(df['verlet_pos0'].iloc[0], df['verlet_pos1'].iloc[0], s=50)
    axes[1].scatter(df['verlet_pos0'].iloc[-1], df['verlet_pos1'].iloc[-1], s=50)
    plt.show()

# %%
plot_trajectories('n10000.csv')
